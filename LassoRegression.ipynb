# %%
import numpy as np
import pandas as pd
from numpy import arange
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV


pa_gs = pd.read_csv('data/pa_data.csv')
X = ['dtr_annual', 'dtr_spring', 'dtr_summer', 'tmax_annual', 'prcp_annual_mm',
    'prcp_spring_mm', 'latitude', 'longitude', 'elevation_m', 'dist_coast_km', 'dist_greatlakes_km', 'dist_atlantic_km',
    'oni_annual', 'nao_annual', 'nao_djf', 'pna_annual', 'amo_annual', 'sst_north_atlantic',
    'sst_gulf_stream', 'sst_gulf_mexico', 'sst_tropical_north_atl', 'pwat_eastern_us', 'pwat_southeast_us', 
    'pwat_northeast_us', 'pwat_gulf_coast', 'pwat_station', 'dewpoint_2m_eastern_us', 'soil_moisture_eastern_us',
    'cloud_cover_eastern_us', 'evaporation_eastern_us', 'dewpoint_2m_southeast_us', 'soil_moisture_southeast_us',
    'cloud_cover_southeast_us', 'evaporation_southeast_us', 'dewpoint_2m_northeast_us', 'soil_moisture_northeast_us',
    'cloud_cover_northeast_us', 'evaporation_northeast_us', 'dewpoint_2m_pennsylvania', 'soil_moisture_pennsylvania',
    'cloud_cover_pennsylvania', 'evaporation_pennsylvania', 'dewpoint_station', 'soil_moisture_station',
    'cloud_cover_station', 'evaporation_station']
y = ['growing_season_length']
def remove_nulls(data_subset, X, y):
        # Drop rows where any of the specified X columns have nulls
        data_subset_cleaned = data_subset.dropna(subset=X, ignore_index=True)
        # Separate the cleaned dataframe back into X and y
        X_cleaned = data_subset_cleaned[X]
        y_cleaned = data_subset_cleaned[y]
        y_cleaned = y_cleaned.squeeze()
        return X_cleaned, y_cleaned

# %%
X_gs, y_gs = remove_nulls(pa_gs, X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_gs, y_gs, test_size = 0.2, random_state = 5)

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
lasso = Lasso()

# %%
lasso.fit(X_train, y_train)
# Out:
# Lasso()

# %%
y_pred = lasso.predict(X_test)

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 13.949572650418807

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 311.7412110973396

# %%
r2_score(y_test, y_pred)
# Out:
# 0.6793730475682505

# %%
param_grid = {
    'alpha' : [0.0065]
}

# %%
lasso_cv = GridSearchCV(lasso, param_grid, cv=3, n_jobs=-1)

# %%
lasso_cv.fit(X_train, y_train)
# Out:
# /home/reu/.venv/lib/python3.14/site-packages/sklearn/linear_model/_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.019832e+02, tolerance: 3.676e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/reu/.venv/lib/python3.14/site-packages/sklearn/linear_model/_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.757431e+03, tolerance: 3.908e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/reu/.venv/lib/python3.14/site-packages/sklearn/linear_model/_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.325470e+03, tolerance: 3.710e+02
#   model = cd_fast.enet_coordinate_descent(
# /home/reu/.venv/lib/python3.14/site-packages/sklearn/linear_model/_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.680260e+03, tolerance: 5.647e+02
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=3, estimator=Lasso(), n_jobs=-1, param_grid={'alpha': [0.0065]})

# %%
y_pred2 = lasso_cv.predict(X_test)

# %%
mean_absolute_error(y_test, y_pred2)
# Out:
# 12.844751586504582

# %%
mean_squared_error(y_test, y_pred2)
# Out:
# 272.82718003322384

# %%
r2_score(y_test, y_pred2)
# Out:
# 0.7193962679278648

# %%
lasso3 = Lasso(alpha=1)
lasso3.fit(X_train, y_train)
# Out:
# Lasso(alpha=1)

# %%
lasso3.intercept_
# Out:
# np.float64(162.2261575673808)

# %%
coefficients = pd.DataFrame(zip(X_gs.columns, lasso3.coef_))
coefficients.columns = ['variables', 'coefficients']
display(coefficients)
# Out:
#                      variables  coefficients
# 0                   dtr_annual    -14.975151
# 1                   dtr_spring     -0.000000
# 2                   dtr_summer     -2.028295
# 3                  tmax_annual     10.556642
# 4               prcp_annual_mm     -0.000000
# 5               prcp_spring_mm     -0.000000
# 6                     latitude     -1.318951
# 7                    longitude      0.000000
# 8                  elevation_m     -7.025536
# 9                dist_coast_km      0.467462
# 10          dist_greatlakes_km      0.000000
# 11            dist_atlantic_km     -0.000000
# 12                  oni_annual     -0.096634
# 13                  nao_annual     -0.000000
# 14                     nao_djf     -0.000000
# 15                  pna_annual      0.000000
# 16                  amo_annual      0.000000
# 17          sst_north_atlantic      1.481549
# 18             sst_gulf_stream      0.000000
# 19             sst_gulf_mexico      0.000000
# 20      sst_tropical_north_atl      0.000000
# 21             pwat_eastern_us      0.000000
# 22           pwat_southeast_us     -0.000000
# 23           pwat_northeast_us      0.000000
# 24             pwat_gulf_coast      0.000000
# 25                pwat_station      0.000000
# 26      dewpoint_2m_eastern_us     -0.000000
# 27    soil_moisture_eastern_us     -0.000000
# 28      cloud_cover_eastern_us     -0.000000
# 29      evaporation_eastern_us      0.000000
# 30    dewpoint_2m_southeast_us     -0.000000
# 31  soil_moisture_southeast_us     -0.000000
# 32    cloud_cover_southeast_us     -0.400506
# 33    evaporation_southeast_us     -0.000000
# 34    dewpoint_2m_northeast_us     -0.000000
# 35  soil_moisture_northeast_us     -1.103432
# 36    cloud_cover_northeast_us     -0.000000
# 37    evaporation_northeast_us      0.759188
# 38    dewpoint_2m_pennsylvania     -0.000000
# 39  soil_moisture_pennsylvania     -0.000000
# 40    cloud_cover_pennsylvania     -0.000000
# 41    evaporation_pennsylvania     -0.000000
# 42            dewpoint_station      0.000000
# 43       soil_moisture_station     -0.000000
# 44         cloud_cover_station     -0.272293
# 45         evaporation_station      0.000000
